# %%
import torch

# %%
torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Out:
# device(type='cuda')

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F # Import F for functional operations
import json
from torch.utils.data import Dataset, DataLoader
from transformers import AutoTokenizer, AutoModelForSequenceClassification

# --- Configuration ---
#oprtional:  modernbert-base
MODEL_ID = "microsoft/deberta-v3-small"
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
LEARNING_RATE = 5e-5
EPOCHS = 3
BATCH_SIZE = 10
MAX_LENGTH = 128

# %%
tokenizer = AutoTokenizer.from_pretrained(MODEL_ID)
if tokenizer.pad_token is None:
        tokenizer.pad_token = tokenizer.eos_token
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/52.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/578 [00:00<?, ?B/s]
# spm.model:   0%|          | 0.00/2.46M [00:00<?, ?B/s]
# /usr/local/lib/python3.12/dist-packages/transformers/convert_slow_tokenizer.py:566: UserWarning: The sentencepiece tokenizer that you are converting to a fast tokenizer uses the byte fallback option which is not implemented in the fast tokenizers. In practice this means that the fast version of the tokenizer can produce unknown tokens whereas the sentencepiece version would have converted these unknown tokens into a sequence of byte tokens matching the original piece of text.
#   warnings.warn(

# %%
class RewardIterableDataset(torch.utils.data.IterableDataset):
    def __init__(self, filename, tokenizer):
        self.filename = filename
        self.tokenizer = tokenizer

    def __iter__(self):
        with open(self.filename, 'r') as f:
            for line in f:
                yield json.loads(line)

    def __getitem__(self, idx):
        return self[idx]

def collate_fn(batch):
    return batch

# %%
dataset = RewardIterableDataset("financial_rewards.jsonl", tokenizer)
dataloader = DataLoader(dataset, batch_size=BATCH_SIZE, collate_fn=collate_fn)

# %%
for batch_idx, batch in enumerate(dataloader):
    print(batch)
# Out:
# [{'prompt': 'User: If I invest $10,000 at a 5% annual interest rate compounded annually, what will be the total amount after 2 years?\nAssistant:', 'chosen': ' Reasoning: To calculate the future value with compound interest, we use the formula A = P(1 + r)^n. Here, P = 10,000, r = 0.05, and n = 2. First year: 10,000 * 1.05 = 10,500. Second year: 10,500 * 1.05 = 11,025.\nAnswer: $11,025', 'rejected': ' You will have around $11,000. Just trust me, 5% adds up.'}, {'prompt': 'User: What does a high P/E ratio generally imply about a stock?\nAssistant:', 'chosen': " Reasoning: A Price-to-Earnings (P/E) ratio compares a company's share price to its earnings per share. A high P/E ratio suggests that investors are expecting higher earnings growth in the future, or that the stock might be overvalued compared to its peers.\nAnswer: It implies high growth expectations or potential overvaluation.", 'rejected': ' Reasoning: P/E stands for Price to Equity.\nAnswer: It means the stock is cheap and you should buy it immediately.'}, {'prompt': 'User: Calculate the Net Profit Margin if Revenue is $500,000 and Net Income is $50,000.\nAssistant:', 'chosen': ' Reasoning: Net Profit Margin is calculated by dividing Net Income by Revenue and multiplying by 100 to get a percentage. Calculation: ($50,000 / $500,000) * 100 = 0.1 * 100 = 10%.\nAnswer: 10%', 'rejected': ' The net profit margin is 50,000/500,000 which is 0.1.'}, {'prompt': 'User: Is it safe to put all my emergency fund into Bitcoin?\nAssistant:', 'chosen': ' Reasoning: An emergency fund requires stability, liquidity, and principal protection to be available for unexpected expenses. Bitcoin is a highly volatile asset class with significant risk of short-term loss.\nAnswer: No, emergency funds should be kept in stable, liquid assets like high-yield savings accounts, not volatile assets.', 'rejected': ' Put it all in crypto. High risk, high reward!'}, {'prompt': 'User: Explain the difference between a stock and a bond.\nAssistant:', 'chosen': ' Reasoning: A stock represents ownership equity in a corporation and entitles the holder to a claim on assets and earnings. A bond is a debt instrument where the investor loans money to an entity for a fixed period at a specific interest rate.\nAnswer: Stock is ownership/equity; Bond is debt/loan.', 'rejected': ' Stocks and bonds are basically the same thing but stocks are for rich people.'}, {'prompt': 'User: A company has current assets of $200k and current liabilities of $100k. What is the Current Ratio?\nAssistant:', 'chosen': " Reasoning: The Current Ratio is a liquidity ratio that measures a company's ability to pay short-term obligations. Formula: Current Assets / Current Liabilities. Calculation: $200,000 / $100,000 = 2.0.\nAnswer: 2.0", 'rejected': ' Answer: 2.0'}, {'prompt': 'User: What is diversification in investing?\nAssistant:', 'chosen': ' Reasoning: Diversification is a risk management strategy that mixes a wide variety of investments within a portfolio. The rationale is that a portfolio constructed of different kinds of assets will, on average, yield higher long-term returns and lower the risk of any individual holding or security.\nAnswer: Spreading investments across various assets to reduce risk.', 'rejected': ' Reasoning: Diversification is buying every stock in the S&P 500.\nAnswer: Buy everything.'}, {'prompt': 'User: Explain the concept of compound interest.\nAssistant:', 'chosen': ' Reasoning: Compound interest is the interest on a loan or deposit calculated based on both the initial principal and the accumulated interest from previous periods. It allows your money to grow faster over time because you earn interest on your interest.\nAnswer: Interest calculated on principal plus accumulated interest.', 'rejected': " It's when the bank pays you free money for no reason."}, {'prompt': 'User: What is a bear market?\nAssistant:', 'chosen': " Reasoning: A bear market is a condition in which securities prices fall and widespread pessi ...
# [{'prompt': 'User: What is an index fund?\nAssistant:', 'chosen': " Reasoning: An index fund is a type of mutual fund or exchange-traded fund (ETF) with a portfolio constructed to match or track the components of a financial market index, such as the Standard & Poor's 500 Index (S&P 500).\nAnswer: A fund that tracks a specific market index.", 'rejected': " It's a fund that outperforms the market every single year."}, {'prompt': 'User: How do tax brackets work in a progressive tax system?\nAssistant:', 'chosen': ' Reasoning: In a progressive tax system, you pay higher tax rates only on the income that falls into higher brackets, not on your total income. E.g., if the 22% bracket starts at $40k, you only pay 22% on the dollars earned *above* $40k, not on the first $40k.\nAnswer: Higher rates apply only to income portions within higher thresholds.', 'rejected': ' If you earn one dollar more and enter a new bracket, you lose net money because your whole income is taxed higher.'}, {'prompt': 'User: What is the rule of 72?\nAssistant:', 'chosen': ' Reasoning: The Rule of 72 is a simple formula used to estimate the number of years required to double the invested money at a given annual rate of return. You divide 72 by the annual rate of return.\nAnswer: Years to double = 72 / Interest Rate.', 'rejected': " Reasoning: It's a rule that says you should retire at age 72.\nAnswer: Retire at 72."}, {'prompt': 'User: What is liquidity?\nAssistant:', 'chosen': ' Reasoning: Liquidity refers to the efficiency or ease with which an asset or security can be converted into ready cash without affecting its market price. Cash is the most liquid asset.\nAnswer: The ease of converting an asset to cash.', 'rejected': ' Liquidity means how much water a company uses.'}, {'prompt': "User: What does 'shorting' a stock mean?\nAssistant:", 'chosen': " Reasoning: Short selling involves borrowing a security and selling it on the open market, planning to buy it back later for less money. Short sellers bet on, and profit from, a drop in a security's price.\nAnswer: Betting against a stock to profit from its price decline.", 'rejected': ' It means buying a stock for a very short period of time.'}, {'prompt': 'User: What is an asset allocation?\nAssistant:', 'chosen': " Reasoning: Asset allocation is an investment strategy that aims to balance risk and reward by apportioning a portfolio's assets according to an individual's goals, risk tolerance, and investment horizon (e.g., 60% stocks, 40% bonds).\nAnswer: Balancing risk by dividing investments among different asset categories.", 'rejected': ' Putting all your money into the asset with the highest past return.'}, {'prompt': 'User: What is a Roth IRA?\nAssistant:', 'chosen': ' Reasoning: A Roth IRA is an Individual Retirement Account where you pay taxes on money going into your account, and then all future withdrawals are tax-free. It differs from a Traditional IRA, where contributions are tax-deductible but withdrawals are taxed.\nAnswer: A retirement account with post-tax contributions and tax-free withdrawals.', 'rejected': " It's a bank account named after David Lee Roth."}, {'prompt': "User: Explain 'opportunity cost'.\nAssistant:", 'chosen': ' Reasoning: Opportunity cost is the potential benefit an investor, individual, or business misses out on when choosing one alternative over another. It quantifies the trade-off of any decision.\nAnswer: The value of the next-best alternative forgone.', 'rejected': ' It means things cost money.'}, {'prompt': 'User: What is a dividend?\nAssistant:', 'chosen': " Reasoning: A dividend is the distribution of some of a company's earnings to a class of its shareholders, as determined by the company's board of directors. It is usually paid in cash.\nAnswer: A portion of corporate profits paid to shareholders.", 'rejected': ' It means the stock price goes up.'}, {'prompt': 'User: What happens if I default on a loan?\nAssistant:', 'chosen': ' Reasoning: Defaulting on a loan mea ...
# [{'prompt': 'User: What is a CD (Certificate of Deposit)?\nAssistant:', 'chosen': ' Reasoning: A CD is a savings product that earns interest on a lump sum for a fixed period. You typically cannot access the funds before the maturity date without paying a penalty.\nAnswer: A time-bound savings deposit with a fixed interest rate.', 'rejected': " It's a music disc from the 90s."}, {'prompt': 'User: What is inflation?\nAssistant:', 'chosen': ' Reasoning: Inflation is the rate at which the general level of prices for goods and services is rising and, consequently, the purchasing power of currency is falling.\nAnswer: The rate of price increases and purchasing power decline.', 'rejected': ' Inflation means the economy is getting bigger.'}, {'prompt': 'User: What is an ETF?\nAssistant:', 'chosen': ' Reasoning: An Exchange Traded Fund (ETF) is a type of security that involves a collection of securities—such as stocks—that tracks an underlying index, although they can invest in any number of industry sectors or use various strategies. ETFs share characteristics with mutual funds but trade on stock exchanges like individual stocks.\nAnswer: A marketable security tracking an index or basket of assets.', 'rejected': ' It stands for Electronic Transfer Fund.'}, {'prompt': "User: Explain 'amortization' in a mortgage.\nAssistant:", 'chosen': ' Reasoning: Amortization is the process of spreading out a loan into a series of fixed payments over time. Your monthly payment remains the same, but the portion going towards interest decreases while the portion going towards principal increases over the life of the loan.\nAnswer: Paying off debt with a fixed schedule of principal and interest.', 'rejected': ' It means you pay the whole house price at the end.'}, {'prompt': 'User: What is a credit score?\nAssistant:', 'chosen': " Reasoning: A credit score is a numerical expression based on a level analysis of a person's credit files, to represent the creditworthiness of an individual. It primarily entails a credit history like timeliness of payments, amount of debt, and length of credit history.\nAnswer: A number rating your creditworthiness.", 'rejected': " It's a score of how much money you have in the bank."}, {'prompt': 'User: What is dollar-cost averaging?\nAssistant:', 'chosen': ' Reasoning: Dollar-cost averaging is an investment strategy in which an investor divides up the total amount to be invested across periodic purchases of a target asset in an effort to reduce the impact of volatility on the overall purchase. You buy more shares when prices are low and fewer when prices are high.\nAnswer: Investing fixed amounts at regular intervals regardless of price.', 'rejected': ' Buying everything when the market is at the very bottom.'}, {'prompt': 'User: What is the difference between a bull and bear market?\nAssistant:', 'chosen': ' Reasoning: A bull market occurs when security prices are rising or are expected to rise, typically accompanied by investor optimism. A bear market is the opposite, characterized by falling prices and widespread pessimism.\nAnswer: Bull market = rising prices; Bear market = falling prices.', 'rejected': ' Bull means strong, Bear means sleeping.'}, {'prompt': 'User: Why is diversification important?\nAssistant:', 'chosen': " Reasoning: Diversification reduces portfolio risk by spreading investments across different asset classes, industries, and geographies. It ensures that the poor performance of one investment doesn't wipe out the entire portfolio.\nAnswer: To minimize risk by spreading investments.", 'rejected': ' To make your portfolio look confusing.'}, {'prompt': 'User: What is a limit order?\nAssistant:', 'chosen': ' Reasoning: A limit order is an order to buy or sell a stock at a specific price or better. A buy limit order can only be executed at the limit price or lower, and a sell limit order can only be executed at the limit price or higher.\nAnswer: An order to trade at a specific price or better.', 'rejected ...
# [{'prompt': 'User: What is a bond yield?\nAssistant:', 'chosen': ' Reasoning: Bond yield is the return an investor realizes on a bond. It is calculated by dividing the annual coupon payment by the current market price of the bond. If prices fall, yields rise.\nAnswer: The return generated by a bond.', 'rejected': ' It means the bond yields to oncoming traffic.'}, {'prompt': 'User: What is the SEC?\nAssistant:', 'chosen': ' Reasoning: The U.S. Securities and Exchange Commission (SEC) is an independent federal government regulatory agency responsible for protecting investors, maintaining fair and orderly functioning of the securities markets, and facilitating capital formation.\nAnswer: The agency regulating U.S. securities markets.', 'rejected': ' The Southeastern Conference in college sports.'}, {'prompt': 'User: What is a 401(k)?\nAssistant:', 'chosen': ' Reasoning: A 401(k) is a retirement savings plan offered by many American employers that has tax advantages to the saver. Employees can contribute a portion of their wages to individual accounts.\nAnswer: An employer-sponsored retirement savings plan.', 'rejected': " It's a race that is 401 kilometers long."}, {'prompt': 'User: What is capital gains tax?\nAssistant:', 'chosen': ' Reasoning: Capital gains tax is a tax on the growth in value of investments incurred when individuals and corporations sell those investments. You only pay it when you sell (realize the gain).\nAnswer: Tax on profit from the sale of an asset.', 'rejected': ' Tax you pay on every dollar you have in the bank.'}, {'prompt': 'User: What is a recession?\nAssistant:', 'chosen': ' Reasoning: A recession is a significant decline in economic activity spread across the economy, lasting more than a few months, normally visible in real GDP, real income, employment, industrial production, and wholesale-retail sales.\nAnswer: A period of significant, widespread economic decline.', 'rejected': ' It means the stock market went down for one day.'}, {'prompt': 'User: What is GDP?\nAssistant:', 'chosen': " Reasoning: Gross Domestic Product (GDP) is the total monetary or market value of all the finished goods and services produced within a country's borders in a specific time period. It functions as a comprehensive scorecard of a given country's economic health.\nAnswer: Total value of goods and services produced by a country.", 'rejected': ' Currently, it is a mystery.'}, {'prompt': 'User: What is volatility?\nAssistant:', 'chosen': " Reasoning: Volatility represents how large an asset's price swings are around the mean price. In finance, it is a measure of risk. High volatility means the price changes dramatically over short periods.\nAnswer: A measure of price variation or risk.", 'rejected': ' It means the stock is electric.'}, {'prompt': 'User: What is a mutual fund?\nAssistant:', 'chosen': ' Reasoning: A mutual fund is a type of financial vehicle made up of a pool of money collected from many investors to invest in securities like stocks, bonds, money market instruments, and other assets. Professional money managers operate the funds.\nAnswer: A pooled investment vehicle managed by professionals.', 'rejected': ' A fund where friends invest together mutually.'}, {'prompt': 'User: What is the difference between revenue and profit?\nAssistant:', 'chosen': ' Reasoning: Revenue is the total amount of income generated by the sale of goods or services. Profit is the amount of income that remains after accounting for all expenses, debts, additional income streams, and operating costs.\nAnswer: Revenue = total sales; Profit = sales minus expenses.', 'rejected': ' There is no difference, they are the same.'}, {'prompt': 'User: What is a balance sheet?\nAssistant:', 'chosen': " Reasoning: A balance sheet is a financial statement that reports a company's assets, liabilities, and shareholders' equity at a specific point in time. It adheres to the equation: Assets = Liabilities + Equity.\nAnswer: A statement of financial posit ...
# [{'prompt': 'User: What is an income statement?\nAssistant:', 'chosen': " Reasoning: An income statement allows you to view a company's revenues and expenses over a specific period of time (e.g., a quarter or year) to determine its profitability.\nAnswer: A report of revenue, expenses, and profit over a period.", 'rejected': ' A statement telling you how much income you should have.'}, {'prompt': 'User: What is cash flow?\nAssistant:', 'chosen': " Reasoning: Cash flow is the net amount of cash and cash-equivalents being transferred into and out of a business. Positive cash flow indicates that a company's liquid assets are increasing.\nAnswer: The movement of money in and out of a business.", 'rejected': ' It means money flowing like a river.'}, {'prompt': 'User: What is equity?\nAssistant:', 'chosen': " Reasoning: In finance, equity represents the value that would be returned to a company's shareholders if all of the assets were liquidated and all of the company's debts were paid off. For a homeowner, it's the difference between the home's value and the mortgage debt.\nAnswer: The value of ownership interest in an asset.", 'rejected': ' Equity means everyone gets paid the same.'}, {'prompt': 'User: What is a hostile takeover?\nAssistant:', 'chosen': " Reasoning: A hostile takeover occurs when an acquiring company attempts to take over a target company against the wishes of the target company's management, typically by buying shares directly from the public or fighting for a proxy vote.\nAnswer: An acquisition against the target management's will.", 'rejected': ' When you take over a meeting aggressively.'}, {'prompt': 'User: What is an IPO?\nAssistant:', 'chosen': ' Reasoning: An Initial Public Offering (IPO) refers to the process of offering shares of a private corporation to the public in a new stock issuance. It allows a company to raise capital from public investors.\nAnswer: Features the first sale of stock by a private company to the public.', 'rejected': ' It stands for International Police Organization.'}, {'prompt': 'User: What is insider trading?\nAssistant:', 'chosen': " Reasoning: Insider trading is the trading of a public company's stock or other securities (such as bonds or stock options) based on material, nonpublic information about the company. Illegal insider trading usually results in jail time.\nAnswer: Trading based on confidential, non-public information.", 'rejected': ' Trading stocks inside your house.'}, {'prompt': 'User: What is leverage?\nAssistant:', 'chosen': " Reasoning: Leverage results from using borrowed capital as a funding source when investing to expand the firm's asset base and generate returns on risk capital. It amplifies both gains and losses.\nAnswer: Using borrowed money to increase potential return.", 'rejected': ' It means lifting heavy weights.'}, {'prompt': 'User: What is a credit union?\nAssistant:', 'chosen': ' Reasoning: A credit union is a member-owned financial cooperative, controlled by its members and operated on the principle of people helping people. They often offer lower rates on loans and higher rates on savings than banks.\nAnswer: A member-owned, non-profit financial cooperative.', 'rejected': ' A union for credit card employees.'}, {'prompt': 'User: What is compounding?\nAssistant:', 'chosen': " Reasoning: Compounding is the process in which an asset's earnings, from either capital gains or interest, are reinvested to generate additional earnings over time. It is exponential growth.\nAnswer: Earning returns on previous returns.", 'rejected': ' Mixing two chemicals together.'}, {'prompt': 'User: What is a fiscal year?\nAssistant:', 'chosen': " Reasoning: A fiscal year is a one-year period that companies and governments use for financial reporting and budgeting. It doesn't necessarily match the calendar year (e.g., starting in October).\nAnswer: A 12-month period for financial reporting.", 'rejected': ' A year where you exercise physically.'}]
# [{'prompt': 'User: What is arbitrage?\nAssistant:', 'chosen': " Reasoning: Arbitrage is the simultaneous purchase and sale of the same asset in different markets to profit from tiny differences in the asset's listed price. It exploits market inefficiencies.\nAnswer: Profiting from price differences in different markets.", 'rejected': ' It means breaking the law.'}, {'prompt': 'User: What is a derivative?\nAssistant:', 'chosen': ' Reasoning: A derivative is a financial security with a value that is reliant upon or derived from an underlying asset or group of assets. Common derivatives include futures, options, and swaps.\nAnswer: A contract whose value comes from an underlying asset.', 'rejected': ' A math problem from calculus class.'}, {'prompt': 'User: What is the Fed?\nAssistant:', 'chosen': ' Reasoning: The Federal Reserve System (the Fed) is the central banking system of the United States. It regulates the money supply, sets interest rates, and aims to maintain financial stability.\nAnswer: The central bank of the United States.', 'rejected': ' A federal agent.'}, {'prompt': 'User: What is quantitative easing?\nAssistant:', 'chosen': ' Reasoning: Quantitative easing (QE) is a form of unconventional monetary policy in which a central bank purchases longer-term securities from the open market in order to increase the money supply and encourage lending and investment.\nAnswer: Central bank buying assets to inject money into economy.', 'rejected': ' Making math problems easier.'}, {'prompt': 'User: What is a hedge fund?\nAssistant:', 'chosen': ' Reasoning: A hedge fund is a limited partnership of private investors whose money is managed by professional fund managers who use a wide range of strategies, including leveraging or trading non-traditional assets, to earn above-average investment returns.\nAnswer: An alternative investment pool for accredited investors.', 'rejected': ' A fund to buy gardening supplies.'}, {'prompt': 'User: What is a blue chip stock?\nAssistant:', 'chosen': ' Reasoning: A blue chip stock is a huge company with an excellent reputation. These are typically large, well-established, and financially sound companies that have operated for many years and often pay dividends.\nAnswer: Stock of a large, reliable, and established company.', 'rejected': ' A stock that is literally blue.'}, {'prompt': 'User: What is common stock?\nAssistant:', 'chosen': ' Reasoning: Common stock is a security that represents ownership in a corporation. Holders of common stock exercise control by electing a board of directors and voting on corporate policy. They are last in line during liquidation.\nAnswer: Equity ownership with voting rights.', 'rejected': " Stock that everyone has, so it's not special."}, {'prompt': 'User: What is preferred stock?\nAssistant:', 'chosen': ' Reasoning: Preferred stock is a class of ownership in a corporation that has a higher claim on its assets and earnings than common stock. Preferred shares generally have a dividend that must be paid out before dividends to common shareholders, but usually carry no voting rights.\nAnswer: Equity with dividend priority but usually no voting rights.', 'rejected': ' Stock that the CEO likes better.'}, {'prompt': 'User: What is a penny stock?\nAssistant:', 'chosen': ' Reasoning: A penny stock typically refers to the stock of a small company that trades for less than $5 per share. They are considered highly speculative and high risk due to lack of liquidity and reporting requirements.\nAnswer: High-risk, low-price stock of a small company.', 'rejected': ' A stock that costs exactly one penny.'}, {'prompt': 'User: What is beta in finance?\nAssistant:', 'chosen': ' Reasoning: Beta is a measure of the volatility—or systematic risk—of a security or portfolio compared to the market as a whole. A beta of 1 indicates the stock moves with the market. >1 is more volatile, <1 is less.\nAnswer: A metric measuring relative volatility/risk.', 'rejected': ' Beta means the second  ...
# [{'prompt': 'User: What is margin trading?\nAssistant:', 'chosen': ' Reasoning: Margin trading involves borrowing funds from a broker to trade a financial asset, which forms the collateral for the loan from the broker. This increases buying power but amplifies risk.\nAnswer: Trading with borrowed money.', 'rejected': ' Trading on the edges of the page.'}, {'prompt': 'User: What is a fiduciary?\nAssistant:', 'chosen': " Reasoning: A fiduciary is a person or organization that acts on behalf of another person or persons, putting their clients' interest ahead of their own, with a duty to preserve good faith and trust.\nAnswer: An advisor legally obligated to act in your best interest.", 'rejected': ' Someone who sells you expensive insurance.'}, {'prompt': 'User: What is a traditional IRA?\nAssistant:', 'chosen': ' Reasoning: A traditional IRA is a type of individual retirement account that allows your contributions to be tax-deductible. Your investment earnings grow tax-deferred until you withdraw them in retirement, at which point they are taxed as income.\nAnswer: Pre-tax contributions, taxed withdrawals.', 'rejected': ' An account for traditional people.'}, {'prompt': 'User: What is an annuity?\nAssistant:', 'chosen': ' Reasoning: An annuity is a financial product that pays out a fixed stream of payments to an individual, primarily used as an income stream for retirees. It is typically created by an insurance company.\nAnswer: An insurance contract providing regular income payments.', 'rejected': ' A yearly birthday party.'}, {'prompt': 'User: What is deflation?\nAssistant:', 'chosen': ' Reasoning: Deflation is a general decline in prices for goods and services, typically associated with a contraction in the supply of money and credit in the economy. It increases the purchasing power of currency over time.\nAnswer: A general decline in prices.', 'rejected': ' When a balloon loses air.'}, {'prompt': 'User: What is stagflation?\nAssistant:', 'chosen': " Reasoning: Stagflation is a persistent high inflation combined with high unemployment and stagnant demand in a country's economy. It is a worst-case scenario for economic policy.\nAnswer: High inflation + high unemployment + slow growth.", 'rejected': ' A party for male deer.'}, {'prompt': 'User: What is a commodity?\nAssistant:', 'chosen': ' Reasoning: A commodity is a basic good used in commerce that is interchangeable with other goods of the same type. Traditional examples include grains, gold, beef, oil, and natural gas.\nAnswer: A raw material or primary agricultural product.', 'rejected': ' Anything you buy at a store.'}, {'prompt': 'User: What is a prospectus?\nAssistant:', 'chosen': ' Reasoning: A prospectus is a formal document that is required by and filed with the Securities and Exchange Commission (SEC) that provides details about an investment offering to the public.\nAnswer: A formal legal document describing a security offering.', 'rejected': ' A person looking for gold.'}, {'prompt': 'User: What is ROI?\nAssistant:', 'chosen': " Reasoning: Return on Investment (ROI) is a performance measure used to evaluate the efficiency or profitability of an investment or compare the efficiency of a number of different investments. ROI tries to directly measure the amount of return on a particular investment, relative to the investment's cost.\nAnswer: A ratio of net profit to cost of investment.", 'rejected': ' Radio On Internet.'}, {'prompt': 'User: What is the S&P 500?\nAssistant:', 'chosen': " Reasoning: The Standards and Poor's 500, or simply the S&P 500, is a stock market index that tracks the performance of 500 large companies listed on stock exchanges in the United States. It is one of the most commonly followed equity indices.\nAnswer: An index of 500 large U.S. publicly traded companies.", 'rejected': ' A race car series.'}]
# [{'prompt': 'User: What is Nasdaq?\nAssistant:', 'chosen': ' Reasoning: The Nasdaq is a global electronic marketplace for buying and selling securities. It is also the name of the index (Nasdaq Composite) that includes almost all stocks listed on the Nasdaq stock exchange, which is heavily weighted towards technology companies.\nAnswer: A tech-heavy U.S. stock exchange.', 'rejected': ' A newly discovered planet.'}, {'prompt': 'User: What is the Dow Jones?\nAssistant:', 'chosen': ' Reasoning: The Dow Jones Industrial Average (DJIA) is a stock market index that tracks 30 prominent companies listed on stock exchanges in the United States. It is one of the oldest and most-watched indices.\nAnswer: An index tracking 30 blue-chip U.S. companies.', 'rejected': ' Mr. Jones from the bank.'}, {'prompt': 'User: What is a trust?\nAssistant:', 'chosen': ' Reasoning: A trust is a fiduciary arrangement where a third party, known as the trustee, holds assets on behalf of a beneficiary or beneficiaries. Trusts can be arranged in many ways and can specify exactly how and when the assets pass to the beneficiaries.\nAnswer: A legal arrangement to hold assets for beneficiaries.', 'rejected': ' It means believing someone.'}, {'prompt': 'User: What is an estate tax?\nAssistant:', 'chosen': " Reasoning: The estate tax is a tax on your right to transfer property at your death. It consists of an accounting of everything you own or have certain interests in at the date of death.\nAnswer: Tax levied on an heir's inherited portion of an estate.", 'rejected': ' Tax on station wagons.'}, {'prompt': 'User: What is a W-2 form?\nAssistant:', 'chosen': " Reasoning: A W-2 form is the document an employer is required to send to each employee and the Internal Revenue Service (IRS) at the end of the year. The form reports the employee's annual wages and the amount of taxes withheld from their paycheck.\nAnswer: A tax form reporting annual wages and withholding.", 'rejected': ' A robot from Star Wars.'}, {'prompt': 'User: What is a 1099 form?\nAssistant:', 'chosen': ' Reasoning: A 1099 form is a record that an entity or person—not your employer—gave or paid you money. It is commonly used for independent contractors, freelancers, and interest/dividend income.\nAnswer: A tax form for non-employment income.', 'rejected': ' A form for buying 1099 items.'}, {'prompt': 'User: What is a standard deduction?\nAssistant:', 'chosen': " Reasoning: The standard deduction is a specific dollar amount that reduces the income on which you're taxed. You can choose between taking the standard deduction or itemizing your deductions.\nAnswer: A fixed amount you can subtract from taxable income.", 'rejected': ' A normal subtraction math problem.'}, {'prompt': 'User: What is net worth?\nAssistant:', 'chosen': ' Reasoning: Net worth is the value of all the non-financial and financial assets that you own minus the value of all your outstanding liabilities. It is a snapshot of your financial health.\nAnswer: Total Assets minus Total Liabilities.', 'rejected': ' How much your net costs.'}, {'prompt': 'User: What is a liability?\nAssistant:', 'chosen': ' Reasoning: In financial accounting, a liability is defined as the future sacrifices of economic benefits that the entity is strictly obliged to make to other entities as a result of past transactions or other past events.\nAnswer: A debt or financial obligation.', 'rejected': ' Someone who is bad at sports.'}, {'prompt': 'User: What is venture capital?\nAssistant:', 'chosen': ' Reasoning: Venture capital is a form of private equity and a type of financing that investors provide to startup companies and small businesses that are believed to have long-term growth potential.\nAnswer: Funding provided to high-potential startups.', 'rejected': ' Capital city of a venture.'}]
# [{'prompt': 'User: What is private equity?\nAssistant:', 'chosen': ' Reasoning: Private equity is an alternative investment class and consists of capital that is not listed on a public exchange. Private equity is composed of funds and investors that directly invest in private companies, or that engage in buyouts of public companies, resulting in the delisting of public equity.\nAnswer: Investments in private companies not traded publicly.', 'rejected': ' Equity that is shy.'}, {'prompt': 'User: What is a bubble?\nAssistant:', 'chosen': " Reasoning: An economic bubble is a situation in which asset prices appear to be based on implausible or inconsistent views about the future. It is a run-up in asset prices fueled by exuberant market behavior that exceeds the asset's intrinsic value.\nAnswer: When asset prices vastly exceed intrinsic value.", 'rejected': ' Soap and water floating in air.'}, {'prompt': 'User: What is a correction?\nAssistant:', 'chosen': ' Reasoning: A market correction is a decline of 10% or more in the price of a security or market index from its most recent peak. Corrections are generally temporary and often viewed as healthy for the market.\nAnswer: A price decline of at least 10%.', 'rejected': ' Fixing a spelling mistake.'}, {'prompt': 'User: What is day trading?\nAssistant:', 'chosen': ' Reasoning: Day trading is the act of buying and selling a financial instrument within the same trading day (or even multiple times over the course of a day), taking advantage of small price moves.\nAnswer: Buying and selling securities within the same day.', 'rejected': ' Trading only during daylight hours.'}, {'prompt': 'User: What is forex?\nAssistant:', 'chosen': ' Reasoning: Forex (FX) is the marketplace where various national currencies are traded. The forex market is the largest, most liquid market in the world, with trillions of dollars changing hands every day.\nAnswer: The global market for trading currencies.', 'rejected': " Four X's."}, {'prompt': 'User: What is cryptocurrency?\nAssistant:', 'chosen': ' Reasoning: A cryptocurrency is a digital or virtual currency that is secured by cryptography, which makes it nearly impossible to counterfeit or double-spend. Many cryptocurrencies are decentralized networks based on blockchain technology.\nAnswer: Secured digital currency using blockchain technology.', 'rejected': ' Money for Superman.'}, {'prompt': 'User: What is the blockchain?\nAssistant:', 'chosen': ' Reasoning: A blockchain is a distributed database or ledger that is shared among the nodes of a computer network. As a database, a blockchain stores information electronically in digital format. It is best known for its crucial role in cryptocurrency systems.\nAnswer: A decentralized, distributed digital ledger.', 'rejected': ' A chain made of blocks.'}, {'prompt': 'User: What is a smart contract?\nAssistant:', 'chosen': ' Reasoning: A smart contract is a self-executing contract with the terms of the agreement between buyer and seller being directly written into lines of code. The code and the agreements contained therein exist across a distributed, decentralized blockchain network.\nAnswer: Self-executing code on a blockchain enforcing an agreement.', 'rejected': ' A contract that went to college.'}, {'prompt': 'User: What is NFT?\nAssistant:', 'chosen': ' Reasoning: A non-fungible token (NFT) is a unique digital identifier that cannot be copied, substituted, or subdivided, that is recorded in a blockchain, and that is used to certify authenticity and ownership.\nAnswer: A unique digital asset verified on a blockchain.', 'rejected': ' No Fun Time.'}, {'prompt': 'User: What is APR?\nAssistant:', 'chosen': " Reasoning: Annual Percentage Rate (APR) refers to the yearly interest generated by a sum that's charged to borrowers or paid to investors. APR is expressed as a percentage that represents the actual yearly cost of funds over the term of a loan.\nAnswer: The annual rate charged for borrowing.", 'rejected': ' ...
# [{'prompt': 'User: What is APY?\nAssistant:', 'chosen': ' Reasoning: Annual Percentage Yield (APY) is the real rate of return earned on a savings deposit or investment taking into account the effect of compounding interest. Unlike APR, APY includes compounding.\nAnswer: Annual rate of return including compounding.', 'rejected': ' Happy.'}, {'prompt': 'User: What is collateral?\nAssistant:', 'chosen': ' Reasoning: Collateral is an asset that a lender accepts as security for a loan. If the borrower defaults on their loan payments, the lender can seize the collateral and sell it to recoup some or all of its losses.\nAnswer: Asset pledged to secure a loan.', 'rejected': ' A lateral move in football.'}, {'prompt': 'User: What is a secured loan?\nAssistant:', 'chosen': " Reasoning: A secured loan is a loan backed by collateral—financial assets you own, like a home or a car—that can be used as payment to the lender if you don't pay back the loan.\nAnswer: A loan backed by collateral.", 'rejected': ' A loan that is kept in a safe.'}, {'prompt': 'User: What is an unsecured loan?\nAssistant:', 'chosen': " Reasoning: An unsecured loan is a loan that is issued and supported only by the borrower's creditworthiness, rather than by any type of collateral. Credit cards and student loans are common examples.\nAnswer: A loan not backed by collateral.", 'rejected': ' A loan that falls out of your pocket.'}, {'prompt': 'User: What is intrinsic value?\nAssistant:', 'chosen': " Reasoning: Intrinsic value is a measure of what an asset is worth. This measure is arrived at by means of an objective calculation or complex financial model, rather than using the currently trading market price of that asset.\nAnswer: The perceived 'true' value of an asset.", 'rejected': ' How much you like something.'}, {'prompt': 'User: What is market capitalization?\nAssistant:', 'chosen': " Reasoning: Market capitalization refers to the total dollar market value of a company's outstanding shares of stock. It is calculated by multiplying the total number of a company's outstanding shares by the current market price of one share.\nAnswer: Total value of outstanding shares.", 'rejected': ' Using capital letters in the market.'}, {'prompt': 'User: What is a ticker symbol?\nAssistant:', 'chosen': ' Reasoning: A ticker symbol is an arrangement of characters (usually letters) representing a particular security listed on an exchange or otherwise traded publicly. E.g., AAPL for Apple.\nAnswer: A unique abbreviation for a publicly traded stock.', 'rejected': ' A symbol that ticks like a clock.'}, {'prompt': 'User: What is a portfolio?\nAssistant:', 'chosen': ' Reasoning: A portfolio is a collection of financial investments like stocks, bonds, commodities, cash, and cash equivalents, including closed-end funds and exchange traded funds (ETFs).\nAnswer: A collection of investments held by an entity.', 'rejected': ' A briefcase for carrying papers.'}, {'prompt': 'User: What is risk tolerance?\nAssistant:', 'chosen': " Reasoning: Risk tolerance is the degree of variability in investment returns that an investor is willing to withstand in their financial planning. It is an important component in investing.\nAnswer: An investor's ability to endure loss.", 'rejected': ' How much you like risky behavior.'}, {'prompt': 'User: What is a benchmark?\nAssistant:', 'chosen': ' Reasoning: A benchmark is a standard against which the performance of a security, mutual fund, or investment manager can be measured. Generally, broad market and market-segment stock and bond indexes are used for this purpose.\nAnswer: A standard for measuring investment performance.', 'rejected': ' A mark on a bench.'}]
# [{'prompt': 'User: What is EBITDA?\nAssistant:', 'chosen': " Reasoning: EBITDA stands for Earnings Before Interest, Taxes, Depreciation, and Amortization. It is a measure of a company's overall financial performance and is used as an alternative to net income in some circumstances.\nAnswer: Earnings measure excluding financing and accounting decisions.", 'rejected': ' Every Body Is Doing Alright.'}, {'prompt': 'User: What is free cash flow?\nAssistant:', 'chosen': ' Reasoning: Free cash flow (FCF) represents the cash a company generates after accounting for cash outflows to support operations and maintain its capital assets. It is a measure of profitability that excludes the non-cash expenses of the income statement and includes spending on equipment and assets.\nAnswer: Cash remaining after op-ex and cap-ex.', 'rejected': ' Cash that is given away for free.'}, {'prompt': 'User: What is a stock split?\nAssistant:', 'chosen': " Reasoning: A stock split is a decision by a company's board of directors to increase the number of shares that are outstanding by issuing more shares to current shareholders. For example, in a 2-for-1 split, an additional share is given for each share held.\nAnswer: Increasing share count while lowering price per share.", 'rejected': ' Breaking a stock certificate in half.'}, {'prompt': 'User: What is a buyback?\nAssistant:', 'chosen': ' Reasoning: A share repurchase, or buyback, is a decision by a company to buy back its own shares from the marketplace. The company might do this because it believes the shares are undervalued or to reduce the number of outstanding shares to increase earnings per share.\nAnswer: Company repurchasing its own shares.', 'rejected': ' Buying something and then returning it.'}, {'prompt': 'User: What is simple interest?\nAssistant:', 'chosen': ' Reasoning: Simple interest is a quick method of calculating the interest charge on a loan. Simple interest is determined by multiplying the daily interest rate by the principal by the number of days that elapse between payments.\nAnswer: Interest calculated only on the principal amount.', 'rejected': " Interest that isn't complicated."}, {'prompt': 'User: What is the prime rate?\nAssistant:', 'chosen': ' Reasoning: The prime rate is the interest rate that commercial banks charge their most creditworthy corporate customers. It serves as a benchmark for other loan rates, such as mortgages and credit cards.\nAnswer: Benchmark rate for best credit customers.', 'rejected': ' The rate for prime steak.'}]

# %%
class RewardModel(nn.Module):
    def __init__(self, base_model_id):
        super().__init__()
        # Initialize as a sequence classifier with 1 label (scalar score)
        self.model = AutoModelForSequenceClassification.from_pretrained(
            base_model_id,
            num_labels=1,
            dtype=torch.float32 # Changed from torch_dtype=torch.float16 to dtype=torch.float32
        )
        # Ensure pad token is set
        if self.model.config.pad_token_id is None:
             self.model.config.pad_token_id = self.model.config.eos_token_id

    def forward(self, input_ids, attention_mask):
        outputs = self.model(input_ids=input_ids, attention_mask=attention_mask)
        return outputs.logits.squeeze(-1) # [batch_size]

# %%
reward_model = RewardModel(MODEL_ID).to(DEVICE)
reward_model.train()
# Out:
# pytorch_model.bin:   0%|          | 0.00/286M [00:00<?, ?B/s]
# Some weights of DebertaV2ForSequenceClassification were not initialized from the model checkpoint at microsoft/deberta-v3-small and are newly initialized: ['classifier.bias', 'classifier.weight', 'pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# RewardModel(
#   (model): DebertaV2ForSequenceClassification(
#     (deberta): DebertaV2Model(
#       (embeddings): DebertaV2Embeddings(
#         (word_embeddings): Embedding(128100, 768, padding_idx=0)
#         (LayerNorm): LayerNorm((768,), eps=1e-07, elementwise_affine=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (encoder): DebertaV2Encoder(
#         (layer): ModuleList(
#           (0-5): 6 x DebertaV2Layer(
#             (attention): DebertaV2Attention(
#               (self): DisentangledSelfAttention(
#                 (query_proj): Linear(in_features=768, out_features=768, bias=True)
#                 (key_proj): Linear(in_features=768, out_features=768, bias=True)
#                 (value_proj): Linear(in_features=768, out_features=768, bias=True)
#                 (pos_dropout): Dropout(p=0.1, inplace=False)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): DebertaV2SelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-07, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): DebertaV2Intermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): DebertaV2Output(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-07, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#         )
#         (rel_embeddings): Embedding(512, 768)
#         (LayerNorm): LayerNorm((768,), eps=1e-07, elementwise_affine=True)
#       )
#     )
#     (pooler): ContextPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (dropout): Dropout(p=0, inplace=False)
#     )
#     (classifier): Linear(in_features=768, out_features=1, bias=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
# )

# %% [markdown]
# # Model training loop
#
#
#
# The model is trained on the selected and rejected answer pairs.
# The loss function used is the bradley terry loss function.
#
# ## Bradley terry loss function
#
# -    The log probabilities of the each sequence (choose and selected are calucualted).
# -    Since every toke has its log prob, the net prob of the entire sequence is calcuated as the meann of all the tokens in a sequence.
# -       loss = -F.logsigmoid(chosen_rewards - rejected_rewards).mean()
# -    It first caulates the difference between the log probabilities of the choose and the reference options.
# -   Second it calculates the sigmoid of the difference.
# -   Third it calculates the Negative log.
#
# -     Hence it calcuates the negative log likehood of difference between the choosen and the selected log probs.
# -   The aim here is to ***maximize*** the difference

# %%
optimizer = optim.AdamW(reward_model.parameters(), lr=LEARNING_RATE)
for epoch in range(EPOCHS):
        total_loss = 0
        batch_count = 0
        for batch_idx, batch in enumerate(dataloader):
            optimizer.zero_grad()

            # Prepare chosen and rejected inputs
            prompts = [item['prompt'] for item in batch]
            chosen_texts = [p + item['chosen'] for p, item in zip(prompts, batch)]
            rejected_texts = [p + item['rejected'] for p, item in zip(prompts, batch)]

            # Tokenize
            chosen_enc = tokenizer(chosen_texts, return_tensors='pt', padding=True, truncation=True, max_length=MAX_LENGTH).to(DEVICE)
            rejected_enc = tokenizer(rejected_texts, return_tensors='pt', padding=True, truncation=True, max_length=MAX_LENGTH).to(DEVICE)

            # Forward pass to get scores
            chosen_rewards = reward_model(chosen_enc.input_ids, chosen_enc.attention_mask)
            rejected_rewards = reward_model(rejected_enc.input_ids, rejected_enc.attention_mask)

            # --- Bradley-Terry Loss ---

            loss = -F.logsigmoid(chosen_rewards - rejected_rewards).mean()

            loss.backward()
            optimizer.step()

            total_loss += loss.item()
            batch_count += 1

        avg_loss = total_loss / batch_count if batch_count > 0 else 0
        print(f"Epoch {epoch+1}/{EPOCHS} | Average Loss: {avg_loss:.4f}")

print("\nTraining complete.")
# Out:
# Epoch 1/3 | Average Loss: 0.5987
# Epoch 2/3 | Average Loss: 0.1019
# Epoch 3/3 | Average Loss: 0.0247
#
# Training complete.

# %%
 # --- Quick Verification ---
print("\n--- Verification: Scoring a sample ---")
reward_model.eval()

# Load just one sample for verification manually
with open("financial_rewards.jsonl", 'r') as f:
    sample = json.loads(f.readline())
prompt = sample['prompt']
chosen = prompt + sample['chosen']
rejected = prompt + sample['rejected']

print(f"Prompt: {prompt}")
print(f"Chosen: {chosen}")
print(f"Rejected: {rejected}")

with torch.no_grad():
    c_enc = tokenizer(chosen, return_tensors='pt').to(DEVICE)
    r_enc = tokenizer(rejected, return_tensors='pt').to(DEVICE)

    c_score = reward_model(c_enc.input_ids, c_enc.attention_mask).item()
    r_score = reward_model(r_enc.input_ids, r_enc.attention_mask).item()

print(f"Chosen Score:   {c_score:.4f}")
print(f"Rejected Score: {r_score:.4f}")

if c_score > r_score:
    print("SUCCESS: Chosen response scored higher.")
else:
    print("FAILURE: Rejected response scored higher (expected with very little training).")
# Out:
# --- Verification: Scoring a sample ---
# Prompt: User: If I invest $10,000 at a 5% annual interest rate compounded annually, what will be the total amount after 2 years?
# Assistant:
# Chosen: User: If I invest $10,000 at a 5% annual interest rate compounded annually, what will be the total amount after 2 years?
# Assistant: Reasoning: To calculate the future value with compound interest, we use the formula A = P(1 + r)^n. Here, P = 10,000, r = 0.05, and n = 2. First year: 10,000 * 1.05 = 10,500. Second year: 10,500 * 1.05 = 11,025.
# Answer: $11,025
# Rejected: User: If I invest $10,000 at a 5% annual interest rate compounded annually, what will be the total amount after 2 years?
# Assistant: You will have around $11,000. Just trust me, 5% adds up.
# Chosen Score:   2.7969
# Rejected Score: -4.6204
# SUCCESS: Chosen response scored higher.

# %%
# %%writefile requirements.txt
# torch
# transformers
# Out:
# Writing requirements.txt

# %%
import os
print(os.listdir('.'))
# Out:
# ['.config', 'requirements.txt', 'financial_rewards.jsonl', 'sample_data']

# %%
# %%writefile data_loader.py
import torch
import json
from torch.utils.data import Dataset, DataLoader

class RewardIterableDataset(torch.utils.data.IterableDataset):
    def __init__(self, filename, tokenizer):
        self.filename = filename
        self.tokenizer = tokenizer

    def __iter__(self):
        with open(self.filename, 'r') as f:
            for line in f:
                yield json.loads(line)

    def __getitem__(self, idx):
        # IterableDatasets typically do not implement __getitem__
        # for direct indexing. This method is a placeholder if needed
        # for compatibility with some DataLoader features that might
        # indirectly call it, but the primary mode of access is __iter__.
        # For this specific use case with DataLoader, __iter__ is sufficient.
        raise NotImplementedError("__getitem__ not implemented for RewardIterableDataset")

def collate_fn(batch):
    return batch
# Out:
# Writing data_loader.py

# %%
# %%writefile reward_model.py
import torch
import torch.nn as nn
from transformers import AutoModelForSequenceClassification

class RewardModel(nn.Module):
    def __init__(self, base_model_id):
        super().__init__()
        # Initialize as a sequence classifier with 1 label (scalar score)
        self.model = AutoModelForSequenceClassification.from_pretrained(
            base_model_id,
            num_labels=1,
            torch_dtype=torch.float32 # Use torch_dtype for AutoModelForSequenceClassification
        )
        # Ensure pad token is set
        if self.model.config.pad_token_id is None:
             self.model.config.pad_token_id = self.model.config.eos_token_id

    def forward(self, input_ids, attention_mask):
        outputs = self.model(input_ids=input_ids, attention_mask=attention_mask)
        return outputs.logits.squeeze(-1) # [batch_size]
# Out:
# Writing reward_model.py

# %%
# %%writefile config.py
import torch

MODEL_ID = "microsoft/deberta-v3-small"
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
LEARNING_RATE = 5e-5
EPOCHS = 3
BATCH_SIZE = 10
MAX_LENGTH = 128
MODEL_SAVE_PATH = "reward_model.pt"
# Out:
# Writing config.py

# %%
import os
print(os.listdir('.'))
# Out:
# ['.config', 'README.md', 'config.py', 'train_reward_model.py', 'reward_model.py', 'data_loader.py', 'requirements.txt', 'financial_rewards.jsonl', 'sample_data']

# %%
# %%writefile train_reward_model.py
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import json
from torch.utils.data import DataLoader
from transformers import AutoTokenizer

# Import modules from our project structure
from data_loader import RewardIterableDataset, collate_fn
from reward_model import RewardModel
import config # Import config.py

# --- Configuration (using config.py) ---
MODEL_ID = config.MODEL_ID
DEVICE = config.DEVICE
LEARNING_RATE = config.LEARNING_RATE
EPOCHS = config.EPOCHS
BATCH_SIZE = config.BATCH_SIZE
MAX_LENGTH = config.MAX_LENGTH
MODEL_SAVE_PATH = config.MODEL_SAVE_PATH # New: Model save path

# --- Tokenizer Initialization ---
tokenizer = AutoTokenizer.from_pretrained(MODEL_ID)
if tokenizer.pad_token is None:
    tokenizer.pad_token = tokenizer.eos_token

# --- Data Loading ---
dataset = RewardIterableDataset("financial_rewards.jsonl", tokenizer)
dataloader = DataLoader(dataset, batch_size=BATCH_SIZE, collate_fn=collate_fn)

# --- Model Initialization ---
reward_model = RewardModel(MODEL_ID).to(DEVICE)
reward_model.train()

# --- Optimizer ---
optimizer = optim.AdamW(reward_model.parameters(), lr=LEARNING_RATE)

# --- Training Loop ---
print("Starting training...")
for epoch in range(EPOCHS):
    total_loss = 0
    batch_count = 0
    for batch_idx, batch in enumerate(dataloader):
        optimizer.zero_grad()

        # Prepare chosen and rejected inputs
        prompts = [item['prompt'] for item in batch]
        chosen_texts = [p + item['chosen'] for p, item in zip(prompts, batch)]
        rejected_texts = [p + item['rejected'] for p, item in zip(prompts, batch)]

        # Tokenize
        chosen_enc = tokenizer(chosen_texts, return_tensors='pt', padding=True, truncation=True, max_length=MAX_LENGTH).to(DEVICE)
        rejected_enc = tokenizer(rejected_texts, return_tensors='pt', padding=True, truncation=True, max_length=MAX_LENGTH).to(DEVICE)

        # Forward pass to get scores
        chosen_rewards = reward_model(chosen_enc.input_ids, chosen_enc.attention_mask)
        rejected_rewards = reward_model(rejected_enc.input_ids, rejected_enc.attention_mask)

        # --- Bradley-Terry Loss ---
        loss = -F.logsigmoid(chosen_rewards - rejected_rewards).mean()

        loss.backward()
        optimizer.step()

        total_loss += loss.item()
        batch_count += 1

    avg_loss = total_loss / batch_count if batch_count > 0 else 0
    print(f"Epoch {epoch+1}/{EPOCHS} | Average Loss: {avg_loss:.4f}")

print("\nTraining complete.")

# --- Save the trained model ---
print(f"Saving reward model to {MODEL_SAVE_PATH}")
torch.save(reward_model.state_dict(), MODEL_SAVE_PATH)
print("Model saved successfully.")

# --- Quick Verification ---
print("\n--- Verification: Scoring a sample ---")
reward_model.eval()

# Load just one sample for verification manually
with open("financial_rewards.jsonl", 'r') as f:
    sample = json.loads(f.readline())
prompt = sample['prompt']
chosen = prompt + sample['chosen']
rejected = prompt + sample['rejected']

print(f"Prompt: {prompt}")
print(f"Chosen: {chosen}")
print(f"Rejected: {rejected}")

with torch.no_grad():
    c_enc = tokenizer(chosen, return_tensors='pt').to(DEVICE)
    r_enc = tokenizer(rejected, return_tensors='pt').to(DEVICE)

    c_score = reward_model(c_enc.input_ids, c_enc.attention_mask).item()
    r_score = reward_model(r_enc.input_ids, r_enc.attention_mask).item()

print(f"Chosen Score:   {c_score:.4f}")
print(f"Rejected Score: {r_score:.4f}")

if c_score > r_score:
    print("SUCCESS: Chosen response scored higher.")
else:
    print("FAILURE: Rejected response scored higher (expected with very little training).")
# Out:
# Overwriting train_reward_model.py

# %%
# %%writefile README.md
# # Reward Model Training Project
#
# This project implements a reward model using a pre-trained transformer model (`microsoft/deberta-v3-small`) to differentiate between chosen and rejected responses based on a dataset of financial questions and answers.
#
# ## Project Structure
# - `requirements.txt`: Lists the Python dependencies.
# - `README.md`: Project documentation.
# - `config.py`: Centralizes all configuration parameters for the training process.
# - `data_loader.py`: Contains the `RewardIterableDataset` and `collate_fn` for loading and processing data.
# - `reward_model.py`: Defines the `RewardModel` architecture.
# - `train_reward_model.py`: Script to train the reward model and save the trained model.
#
# ## Setup and Installation
# 1. Clone this repository (if applicable).
# 2. Create a virtual environment (optional but recommended):
#    `python -m venv venv`
#    `source venv/bin/activate` (on Linux/macOS)
#    `.\venv\Scripts\activate` (on Windows)
# 3. Install the required packages:
#    `pip install -r requirements.txt`
#
# ## Configuration
# All training parameters are defined in `config.py`, including `MODEL_ID`, `DEVICE`, `LEARNING_RATE`, `EPOCHS`, `BATCH_SIZE`, `MAX_LENGTH`, and `MODEL_SAVE_PATH`.
#
# ## Data
# The model is trained on a JSONL file named `financial_rewards.jsonl`, which contains entries with `prompt`, `chosen`, and `rejected` fields.
#
# ## Training
# To train the reward model, run the `train_reward_model.py` script:
# `python train_reward_model.py`
#
# The trained model will be saved to the path specified in `config.MODEL_SAVE_PATH` (default: `reward_model.pt`).
#
# ## Model Details
# - **Base Model**: `microsoft/deberta-v3-small` (configured in `config.py`)
# - **Loss Function**: Bradley-Terry loss
# - **Optimizer**: AdamW
# - **Learning Rate**: 5e-5 (configured in `config.py`)
# - **Epochs**: 3 (configured in `config.py`)
# - **Batch Size**: 10 (configured in `config.py`)
# - **Max Length**: 128 (configured in `config.py`)
# Out:
# Overwriting README.md

# %%
import os
print(os.listdir('.'))
# Out:
# ['.config', 'README.md', 'config.py', 'train_reward_model.py', 'reward_model.py', 'data_loader.py', 'requirements.txt', 'financial_rewards.jsonl', 'sample_data']
